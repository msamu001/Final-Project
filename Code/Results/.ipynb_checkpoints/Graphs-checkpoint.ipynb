# %%
import matplotlib.pyplot as plt
import numpy as np

X1 = ([13.6363,13.4897,12.8299,12.2067,11.5102,10.9237,10.9237,10.9237,10.9237,10.0073,10.0073,10.0073,10.0073,10.0073,10.0073,9.9340,9.9340,9.9340,9.9340,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.4208,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475,9.3475])

plt.plot(X1)
plt.title('Cost vs Iteration')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.show()
