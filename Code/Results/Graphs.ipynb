# %%
import matplotlib.pyplot as plt
import numpy as np

XA = ([9.8012,9.8012,9.8012,9.8012,9.8012,9.4399,8.4010,7.3170,7.3170,7.3170,7.3170,7.3170,7.3170,7.3170,7.3170,7.2267,7.2267,7.2267,7.2267,7.2267,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,7.0009,6.9557,6.9557,6.9557,6.9557,6.9557,6.9557,6.9557,6.9557,6.9557,6.9557,6.9105,6.9105,6.9105,6.9105,6.9105,6.9105,6.9105,6.8654,6.8654,6.8654,6.8654,6.8654,6.8654,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750])
    
XB = ([6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750,6.7750])
    
XC = ([2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842,2.8842])
    

plt.plot(XA)
plt.xlabel('Iteration')
plt.ylabel('Fitness')
#plt.ylim(ymin = 6.7750)
plt.show()

plt.plot(XB)
plt.xlabel('Iteration')
plt.ylabel('Fitness')
#plt.ylim(y_min = 6.7750)
plt.show()

plt.plot(XC)
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.show()
